# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv(r'C:\Users\User\Desktop\data_hub\udemy_courses.csv',parse_dates=['published_timestamp'])

# %%
data.head(3)
# Out:
#    course_id                                       course_title  \
# 0    1070968                 Ultimate Investment Banking Course
# 1    1113822  Complete GST Course & Certification - Grow You...
# 2    1006314  Financial Modeling for Business Analysts and C...
#
#                                                  url  is_paid  price  \
# 0  https://www.udemy.com/ultimate-investment-bank...     True    200
# 1      https://www.udemy.com/goods-and-services-tax/     True     75
# 2  https://www.udemy.com/financial-modeling-for-b...     True     45
#
#    num_subscribers  num_reviews  num_lectures               level  \
# 0             2147           23            51          All Levels
# 1             2792          923           274          All Levels
# 2             2174           74            51  Intermediate Level
#
#    content_duration       published_timestamp           subject
# 0               1.5 2017-01-18 20:58:58+00:00  Business Finance
# ...

# %%
data.shape
# Out:
# (3678, 12)

# %%
data.columns
# Out:
# Index(['course_id', 'course_title', 'url', 'is_paid', 'price',
#        'num_subscribers', 'num_reviews', 'num_lectures', 'level',
#        'content_duration', 'published_timestamp', 'subject'],
#       dtype='object')

# %%
data.isnull().sum()
# Out:
# course_id              0
# course_title           0
# url                    0
# is_paid                0
# price                  0
# num_subscribers        0
# num_reviews            0
# num_lectures           0
# level                  0
# content_duration       0
# published_timestamp    0
# subject                0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3678 entries, 0 to 3677
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   course_id            3678 non-null   int64
#  1   course_title         3678 non-null   object
#  2   url                  3678 non-null   object
#  3   is_paid              3678 non-null   bool
#  4   price                3678 non-null   int64
#  5   num_subscribers      3678 non-null   int64
#  6   num_reviews          3678 non-null   int64
#  7   num_lectures         3678 non-null   int64
#  8   level                3678 non-null   object
#  9   content_duration     3678 non-null   float64
#  10  published_timestamp  3678 non-null   datetime64[ns, UTC]
#  11  subject              3678 non-null   object
# dtypes: bool(1), datetime64[ns, UTC](1), float64(1), int64(5), object(4)
# memory usage: 319.8+ KB

# %%
data.describe(include='all')
# Out:
#            course_id                   course_title  \
# count   3.678000e+03                           3678
# unique           NaN                           3663
# top              NaN  Acoustic Blues Guitar Lessons
# freq             NaN                              3
# mean    6.759720e+05                            NaN
# min     8.324000e+03                            NaN
# 25%     4.076925e+05                            NaN
# 50%     6.879170e+05                            NaN
# 75%     9.613555e+05                            NaN
# max     1.282064e+06                            NaN
# std     3.432732e+05                            NaN
#
#                                                       url is_paid  \
# count                                                3678    3678
# unique                                               3672       2
# top     https://www.udemy.com/cfa-level-2-quantitative...    True
# freq                                                    2    3368
# ...

# %%
sns.heatmap(data.isnull())
# Out:
# <Axes: >

# %%
data.duplicated().any()
# Out:
# True

# %%
data.drop_duplicates(inplace=True)

# %%
data.shape
# Out:
# (3672, 12)

# %%
data.columns
# Out:
# Index(['course_id', 'course_title', 'url', 'is_paid', 'price',
#        'num_subscribers', 'num_reviews', 'num_lectures', 'level',
#        'content_duration', 'published_timestamp', 'subject'],
#       dtype='object')

# %%
data.columns
# Out:
# Index(['course_id', 'course_title', 'url', 'is_paid', 'price',
#        'num_subscribers', 'num_reviews', 'num_lectures', 'level',
#        'content_duration', 'published_timestamp', 'subject'],
#       dtype='object')

# %%
data['level'].value_counts().plot(kind='bar')
plt.show()

# %%
data['level'].value_counts()
# Out:
# level
# All Levels            1925
# Beginner Level        1268
# Intermediate Level     421
# Expert Level            58
# Name: count, dtype: int64

# %%
data['is_paid'].value_counts()
# Out:
# is_paid
# True     3362
# False     310
# Name: count, dtype: int64

# %%
sns.countplot(x='is_paid',data=data)
# Out:
# <Axes: xlabel='is_paid', ylabel='count'>

# %%
data['subject'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='subject'>

# %%
data.columns
# Out:
# Index(['course_id', 'course_title', 'url', 'is_paid', 'price',
#        'num_subscribers', 'num_reviews', 'num_lectures', 'level',
#        'content_duration', 'published_timestamp', 'subject'],
#       dtype='object')

# %%
data.groupby('is_paid')['num_lectures'].mean().round(2)
# Out:
# is_paid
# False    21.42
# True     41.87
# Name: num_lectures, dtype: float64

# %%
data.groupby('is_paid')['num_lectures'].describe()
# Out:
#           count       mean        std  min   25%   50%   75%    max
# is_paid
# False     310.0  21.416129  18.322119  5.0  11.0  17.0  25.0  145.0
# True     3362.0  41.866746  52.059119  0.0  15.0  26.0  48.0  779.0

# %%
data.groupby('is_paid')['num_subscribers'].sum().sort_values(ascending=False).plot(kind='bar')
# Out:
# <Axes: xlabel='is_paid'>

# %%
sns.barplot(x='is_paid',y='num_subscribers',data=data)
# Out:
# <Axes: xlabel='is_paid', ylabel='num_subscribers'>

# %%
data.groupby('level')['num_subscribers'].sum().plot(kind='bar')
# Out:
# <Axes: xlabel='level'>

# %%
plt.figure(figsize=(10,4))
sns.barplot(x='level',y='num_subscribers',data=data)
# Out:
# <Axes: xlabel='level', ylabel='num_subscribers'>

# %%
data.groupby('course_title')['num_subscribers'].sum().sort_values(ascending=False).head(20)
# Out:
# course_title
# Learn HTML5 Programming From Scratch                            268923
# Coding for Entrepreneurs Basic                                  161029
# The Web Developer Bootcamp                                      121584
# Build Your First Website in 1 Week with HTML5 and CSS3          120291
# The Complete Web Developer Course 2.0                           114512
# Free Beginner Electric Guitar Lessons                           101154
# Web Design for Web Developers: Build Beautiful Websites!         98867
# Learn Javascript & JQuery From Scratch                           84897
# Practical PHP: Master the Basics and Code Dynamic Websites       83737
# JavaScript: Understanding the Weird Parts                        79612
# Pianoforall - Incredible New Way To Learn Piano & Keyboard       75499
# Angular 4 (formerly Angular 2) - The Complete Guide              73783
# Beginner Photoshop to HTML5 and CSS3                             73110
# ...

# %%
data[data['num_subscribers']==data['num_subscribers'].max()]
# Out:
#       course_id                          course_title  \
# 2827      41295  Learn HTML5 Programming From Scratch
#
#                                                     url  is_paid  price  \
# 2827  https://www.udemy.com/learn-html5-programming-...    False      0
#
#       num_subscribers  num_reviews  num_lectures       level  \
# 2827           268923         8629            45  All Levels
#
#       content_duration       published_timestamp          subject
# 2827              10.5 2013-02-14 07:03:41+00:00  Web Development

# %%
data.columns
# Out:
# Index(['course_id', 'course_title', 'url', 'is_paid', 'price',
#        'num_subscribers', 'num_reviews', 'num_lectures', 'level',
#        'content_duration', 'published_timestamp', 'subject'],
#       dtype='object')

# %%
data.groupby('course_title')['num_subscribers'].sum().sort_values(ascending=False).head(10)
# Out:
# course_title
# Learn HTML5 Programming From Scratch                          268923
# Coding for Entrepreneurs Basic                                161029
# The Web Developer Bootcamp                                    121584
# Build Your First Website in 1 Week with HTML5 and CSS3        120291
# The Complete Web Developer Course 2.0                         114512
# Free Beginner Electric Guitar Lessons                         101154
# Web Design for Web Developers: Build Beautiful Websites!       98867
# Learn Javascript & JQuery From Scratch                         84897
# Practical PHP: Master the Basics and Code Dynamic Websites     83737
# JavaScript: Understanding the Weird Parts                      79612
# Name: num_subscribers, dtype: int64

# %%
data.sort_values(by='num_subscribers',ascending=False).head(10)
# Out:
#       course_id                                       course_title  \
# 2827      41295               Learn HTML5 Programming From Scratch
# 3032      59014                     Coding for Entrepreneurs Basic
# 3230     625204                         The Web Developer Bootcamp
# 2783     173548  Build Your First Website in 1 Week with HTML5 ...
# 3232     764164              The Complete Web Developer Course 2.0
# 1896      19421              Free Beginner Electric Guitar Lessons
# 2589     473160  Web Design for Web Developers: Build Beautiful...
# 2619      94430             Learn Javascript & JQuery From Scratch
# 3289     130064  Practical PHP: Master the Basics and Code Dyna...
# 3247     364426          JavaScript: Understanding the Weird Parts
#
#                                                     url  is_paid  price  \
# 2827  https://www.udemy.com/learn-html5-programming-...    False      0
# 3032  https://www.udemy.com/coding-for-entrepreneurs...    False      0
# ...

# %%
top_10=data.sort_values(by='num_subscribers',ascending=False).head(10)

# %%
top_10
# Out:
#       course_id                                       course_title  \
# 2827      41295               Learn HTML5 Programming From Scratch
# 3032      59014                     Coding for Entrepreneurs Basic
# 3230     625204                         The Web Developer Bootcamp
# 2783     173548  Build Your First Website in 1 Week with HTML5 ...
# 3232     764164              The Complete Web Developer Course 2.0
# 1896      19421              Free Beginner Electric Guitar Lessons
# 2589     473160  Web Design for Web Developers: Build Beautiful...
# 2619      94430             Learn Javascript & JQuery From Scratch
# 3289     130064  Practical PHP: Master the Basics and Code Dyna...
# 3247     364426          JavaScript: Understanding the Weird Parts
#
#                                                     url  is_paid  price  \
# 2827  https://www.udemy.com/learn-html5-programming-...    False      0
# 3032  https://www.udemy.com/coding-for-entrepreneurs...    False      0
# ...

# %%
sns.barplot(x='num_subscribers',y='course_title',data=top_10)
# Out:
# <Axes: xlabel='num_subscribers', ylabel='course_title'>

# %%
highest_reviews=data.sort_values(by='num_reviews',ascending=False).head(10)

# %%
highest_reviews
# Out:
#       course_id                                       course_title  \
# 3230     625204                         The Web Developer Bootcamp
# 3232     764164              The Complete Web Developer Course 2.0
# 3204     756150  Angular 4 (formerly Angular 2) - The Complete ...
# 3247     364426          JavaScript: Understanding the Weird Parts
# 3254     705264                            Modern React with Redux
# 3246     289230                     Learn and Understand AngularJS
# 3251     461160                        Learn and Understand NodeJS
# 2827      41295               Learn HTML5 Programming From Scratch
# 3228     719002  Angular 2 with TypeScript for Beginners: The P...
# 1979     238934  Pianoforall - Incredible New Way To Learn Pian...
#
#                                                     url  is_paid  price  \
# 3230  https://www.udemy.com/the-web-developer-bootcamp/     True    200
# 3232  https://www.udemy.com/the-complete-web-develop...     True    200
# ...

# %%
sns.barplot(x='num_reviews',y='course_title',data=highest_reviews)
# Out:
# <Axes: xlabel='num_reviews', ylabel='course_title'>

# %%
plt.figure(figsize=(10,4))
sns.barplot(x='subject',y='num_reviews',data=data)
# Out:
# <Axes: xlabel='subject', ylabel='num_reviews'>

# %%
data.groupby('price')['num_reviews'].sum().sort_values(ascending=False).head(20)
# Out:
# price
# 0      132038
# 200    100831
# 195     52469
# 190     34075
# 175     29616
# 150     29611
# 20      27107
# 50      26427
# 180     16839
# 100     14778
# 75      12490
# 30      11505
# 95       9962
# 60       9244
# 40       7306
# 120      6874
# 145      6533
# 25       6003
# 110      5183
# 140      5127
# Name: num_reviews, dtype: int64

# %%
plt.figure(figsize=(10,4))
sns.scatterplot(x='price',y='num_reviews',data=data)
# Out:
# <Axes: xlabel='price', ylabel='num_reviews'>

# %%
len(data[data['course_title'].str.contains('python',case=False)])
# Out:
# 29

# %%
data_python=data[data['course_title'].str.contains('python',case=False)].sort_values(by='num_subscribers',ascending=False).head(10)

# %%
data_python
# Out:
#       course_id                                       course_title  \
# 2497      16646                        Web Programming with Python
# 2570      47963  Coding for Entrepreneurs: Learn Python, Django...
# 2528     391546        Learn Python and Django: Payment Processing
# 3200     822444  Python and Django Full Stack Web Developer Boo...
# 3507     394832  Fun and creative web engineering with Python a...
# 2553     938560  The Complete Ethical Hacking Course 2.0: Pytho...
# 3138     631128  Complete Python Web Course: Build 8 Python Web...
# 3197      76052  Try Django 1.9 | Build a Blog and Learn Python...
# 2681     477702  Python for Beginners: Python Programming Langu...
# 3203     970600                    REST APIs with Flask and Python
#
#                                                     url  is_paid  price  \
# 2497  https://www.udemy.com/web-programming-with-pyt...     True     50
# 2570    https://www.udemy.com/coding-for-entrepreneurs/     True    195
# ...

# %%
sns.barplot(x='num_subscribers',y='course_title',data=data_python)
plt.show()

# %%
data.columns
# Out:
# Index(['course_id', 'course_title', 'url', 'is_paid', 'price',
#        'num_subscribers', 'num_reviews', 'num_lectures', 'level',
#        'content_duration', 'published_timestamp', 'subject'],
#       dtype='object')

# %%
data.dtypes
# Out:
# course_id                            int64
# course_title                        object
# url                                 object
# is_paid                               bool
# price                                int64
# num_subscribers                      int64
# num_reviews                          int64
# num_lectures                         int64
# level                               object
# content_duration                   float64
# published_timestamp    datetime64[ns, UTC]
# subject                             object
# dtype: object

# %%
data['published_timestamp']
# Out:
# 0      2017-01-18 20:58:58+00:00
# 1      2017-03-09 16:34:20+00:00
# 2      2016-12-19 19:26:30+00:00
# 3      2017-05-30 20:07:24+00:00
# 4      2016-12-13 14:57:18+00:00
#                   ...
# 3673   2016-06-14 17:36:46+00:00
# 3674   2017-03-10 22:24:30+00:00
# 3675   2015-12-30 16:41:42+00:00
# 3676   2016-08-11 19:06:15+00:00
# 3677   2014-09-28 19:51:11+00:00
# Name: published_timestamp, Length: 3672, dtype: datetime64[ns, UTC]

# %%
data['year']=data['published_timestamp'].dt.year

# %%
data.head()
# Out:
#    course_id                                       course_title  \
# 0    1070968                 Ultimate Investment Banking Course
# 1    1113822  Complete GST Course & Certification - Grow You...
# 2    1006314  Financial Modeling for Business Analysts and C...
# 3    1210588  Beginner to Pro - Financial Analysis in Excel ...
# 4    1011058       How To Maximize Your Profits Trading Options
#
#                                                  url  is_paid  price  \
# 0  https://www.udemy.com/ultimate-investment-bank...     True    200
# 1      https://www.udemy.com/goods-and-services-tax/     True     75
# 2  https://www.udemy.com/financial-modeling-for-b...     True     45
# 3  https://www.udemy.com/complete-excel-finance-c...     True     95
# 4  https://www.udemy.com/how-to-maximize-your-pro...     True    200
#
#    num_subscribers  num_reviews  num_lectures               level  \
# 0             2147           23            51          All Levels
# ...

# %%
sns.countplot(x='year',data=data)
# Out:
# <Axes: xlabel='year', ylabel='count'>

# %%
data.groupby('year')['subject'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='year,subject'>

# %%
data.groupby('year')['subject'].value_counts()
# Out:
# year  subject
# 2011  Web Development          5
# 2012  Web Development         19
#       Musical Instruments     10
#       Graphic Design          10
#       Business Finance         6
# 2013  Business Finance        84
#       Web Development         55
#       Musical Instruments     39
#       Graphic Design          23
# 2014  Business Finance       192
#       Musical Instruments    120
#       Web Development        113
#       Graphic Design          65
# 2015  Business Finance       339
#       Web Development        336
#       Musical Instruments    171
#       Graphic Design         168
# 2016  Web Development        448
#       Business Finance       347
#       Musical Instruments    228
#       Graphic Design         181
# 2017  Web Development        223
#       Business Finance       223
#       Graphic Design         155
#       Musical Instruments    112
# Name: count, dtype: int64
